# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv(r'C:\Users\rana_\IronhackDA\DAFT_212\module_2\Project_Week_4\diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         color         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940      3.405803     61.749405     57.457184   3932.799722
# std        0.474011      1.701105      1.432621      2.234491   3989.439738
# min        0.200000      0.000000     43.000000     43.000000    326.000000
# 25%        0.400000      2.000000     61.000000     56.000000    950.000000
# 50%        0.700000      3.000000     61.800000     57.000000   2401.000000
# 75%        1.040000      5.000000     62.500000     59.000000   5324.250000
# max        5.010000      6.000000     79.000000     95.000000  18823.000000
#
#                   x             y             z   clarity_cat
# count  53940.000000  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734148      3.538274      3.051020
# std        1.121761      1.136871      0.694964      1.647136
# min        0.000000      0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000      2.000000
# 50%        5.700000      5.710000      3.530000      3.000000
# 75%        6.540000      6.540000      4.040000      4.000000
# max       10.740000     58.900000      8.060000      7.000000

# %%
diamonds
# Out:
#        carat        cut  color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal      5     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium      5     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good      5     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium      1     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good      0     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...    ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal      6     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good      6     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good      6     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium      2     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal      6     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity_cat
# 0                1
# 1                2
# 2                4
# 3                3
# 4                1
# ...            ...
# 53935            2
# 53936            2
# 53937            2
# 53938            1
# 53939            1
#
# [53940 rows x 11 columns]

# %%
#your comments here

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %% [markdown]
# #your hypotheses here
# My hypotheses:
#     Carat and clarity are more correlated with the price, when the carat and clarity are great the price is higher

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby(diamonds['color']).mean().round(4)
# Out:
#         carat    depth    table      price       x       y       z  \
# color
# 0      1.1621  61.8872  57.8124  5323.8180  6.5193  6.5181  4.0333
# 1      1.0269  61.8464  57.5773  5091.8750  6.2228  6.2227  3.8454
# 2      0.9118  61.8368  57.5178  4486.6692  5.9833  5.9848  3.6960
# 3      0.7712  61.7571  57.2886  3999.1357  5.6775  5.6802  3.5054
# 4      0.7365  61.6946  57.4335  3724.8864  5.6150  5.6195  3.4644
# 5      0.6579  61.6621  57.4912  3076.7525  5.4116  5.4169  3.3378
# 6      0.6578  61.6981  57.4046  3169.9541  5.4171  5.4211  3.3428
#
#        clarity_cat
# color
# 0           2.7764
# 1           2.9640
# 2           2.9336
# 3           3.4634
# 4           3.1339
# 5           2.9699
# 6           2.6915

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
data1= diamonds['color'].value_counts()
data1
# Out:
# 3    11292
# 5     9797
# 4     9542
# 2     8304
# 6     6775
# 1     5422
# 0     2808
# Name: color, dtype: int64

# %%
frequencies=pd.DataFrame(diamonds['color'].value_counts())
frequencies
# Out:
#    color
# 3  11292
# 5   9797
# 4   9542
# 2   8304
# 6   6775
# 1   5422
# 0   2808

# %%
frequencies.plot(kind= "bar")
# Out:
# <AxesSubplot:>

# %%
#your comments here
 The color 3 is the most frequent

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here

diamonds.groupby(diamonds['carat']).mean().round(4)
# Out:
#         color    depth    table       price        x        y       z  \
# carat
# 0.20   5.1667  61.1000  59.3333    365.1667   3.7867   3.7533  2.3033
# 0.21   5.4444  60.5111  58.4444    380.2222   3.8744   3.8378  2.3322
# 0.22   4.8000  61.6200  60.4000    391.4000   3.8980   3.8480  2.3860
# 0.23   4.5188  61.4266  58.0341    486.1433   3.9464   3.9734  2.4315
# 0.24   4.1850  61.5992  57.4882    505.1850   3.9902   4.0193  2.4656
# ...       ...      ...      ...         ...      ...      ...     ...
# 4.00   1.0000  63.3000  58.0000  15984.0000  10.0100   9.9400  6.3100
# 4.01   0.5000  61.7500  61.5000  15223.0000  10.0800  10.0200  6.2050
# 4.13   2.0000  64.8000  61.0000  17329.0000  10.0000   9.8500  6.4300
# 4.50   0.0000  65.8000  58.0000  18531.0000  10.2300  10.1600  6.7200
# 5.01   0.0000  65.5000  59.0000  18018.0000  10.7400  10.5400  6.9800
#
#        clarity_cat
# carat
# 0.20        2.8333
# 0.21        2.6667
# 0.22        2.6000
# 0.23        4.9010
# 0.24        4.9724
# ...            ...
# 4.00        0.0000
# 4.01        0.0000
# 4.13        0.0000
# 4.50        0.0000
# 5.01        0.0000
#
# [273 rows x 8 columns]

# %%
#your comments
diamonds['price'].corr(diamonds['color']) 
#negative correlation but law
# Out:
# -0.17251092815346702

# %%
diamonds['price'].corr(diamonds['carat']) 
#very strong correlation
# Out:
# 0.9215913011934712

# %%
diamonds['price'].corr(diamonds['clarity_cat']) 
#low correlation
# Out:
# -0.14680007107895002

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds['carat'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# price has a corelation with carat and color.

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby(diamonds['table']).mean().round(4)
# Out:
#         carat  color  depth    price      x      y      z  clarity_cat
# table
# 43.0   1.0400    1.0  62.90   4997.0  6.450  6.410  4.040         4.00
# 44.0   0.2900    5.0  62.80    474.0  4.200  4.240  2.650         4.00
# 49.0   0.6500    3.0  64.25   2290.5  5.355  5.320  3.425         3.00
# 50.0   1.5100    3.0  61.50   8995.5  7.380  7.295  4.510         2.00
# 50.1   0.9400    2.0  66.00   3353.0  6.130  6.170  4.060         1.00
# ...       ...    ...    ...      ...    ...    ...    ...          ...
# 71.0   0.6800    3.0  58.00   1633.0  5.850  5.700  3.350         2.00
# 73.0   0.6025    4.5  68.90   2406.5  5.520  5.465  3.745         3.25
# 76.0   0.7900    3.0  65.30   2362.0  5.520  5.130  3.350         2.00
# 79.0   0.8100    4.0  68.80   2301.0  5.260  5.200  3.580         1.00
# 95.0   2.0100    4.0  58.60  13387.0  8.320  8.310  4.870         2.00
#
# [127 rows x 8 columns]

# %% [markdown]
# #your comments here
# table/size of the diamonds seems not correled with price

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby(diamonds['clarity_cat']).mean().round(4)
# Out:
#               carat   color    depth    table      price       x       y  \
# clarity_cat
# 0            1.2838  2.9690  62.7343  58.3038  3924.1687  6.7611  6.7094
# 1            1.0776  3.4700  61.7722  57.9272  5063.0286  6.4014  6.3978
# 2            0.8505  3.4485  61.8530  57.6625  3996.0011  5.8884  5.8883
# 3            0.7639  3.4942  61.7244  57.4174  3924.9894  5.6577  5.6589
# 4            0.7272  3.1618  61.6675  57.3152  3839.4554  5.5722  5.5793
# 5            0.5962  3.5695  61.6638  57.0250  3283.7371  5.2185  5.2321
# 6            0.5033  3.3516  61.6247  56.8845  2523.1146  4.9604  4.9751
# 7            0.5051  3.1017  61.5106  56.5072  2864.8391  4.9684  4.9898
#
#                   z
# clarity_cat
# 0            4.2079
# 1            3.9489
# 2            3.6398
# 3            3.4915
# 4            3.4375
# 5            3.2215
# 6            3.0613
# 7            3.0617

# %%
#your comments here

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
diamonds.corr()
Carat has te highest correlation with price then the dimensions of the diamond.
# Out:
#                 carat     color     depth     table     price         x  \
# carat        1.000000 -0.291437  0.028224  0.181618  0.921591  0.975094
# color       -0.291437  1.000000 -0.047279 -0.026465 -0.172511 -0.270287
# depth        0.028224 -0.047279  1.000000 -0.295779 -0.010647 -0.025289
# table        0.181618 -0.026465 -0.295779  1.000000  0.127134  0.195344
# price        0.921591 -0.172511 -0.010647  0.127134  1.000000  0.884435
# x            0.975094 -0.270287 -0.025289  0.195344  0.884435  1.000000
# y            0.956331 -0.265116 -0.029488  0.184976  0.869583  0.979387
# z            0.968621 -0.273110  0.096173  0.154273  0.874908  0.986258
# clarity_cat -0.352841 -0.025631 -0.067384 -0.160327 -0.146800 -0.371999
#
#                     y         z  clarity_cat
# carat        0.956331  0.968621    -0.352841
# color       -0.265116 -0.273110    -0.025631
# depth       -0.029488  0.096173    -0.067384
# table        0.184976  0.154273    -0.160327
# price        0.869583  0.874908    -0.146800
# x            0.979387  0.986258    -0.371999
# y            1.000000  0.970890    -0.360271
# z            0.970890  1.000000    -0.373188
# clarity_cat -0.360271 -0.373188     1.000000

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %% [markdown]
# #your thoughts here
# hight correlation with carat, price, and the dimensions of the diamond (x, y, z)

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
x =plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# C:\Users\rana_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2

slope
# Out:
# 7756.425617968343

# %% [markdown]
# **What do you think?**

# %% [markdown]
# #your thoughts here
# There is a very strong correlation between carat and the price.  when the carat increases one point the price increases 7756.42 $

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
diamonds.price.describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
#your thoughts here
FaceGrid.set(ylim=(0, 40000))

# %%
a =plt.figure(figsize=(10, 10))
sns.FacetGrid(diamonds, col='x', row='price')
plt.ylim(0,20000)

# %%
a =plt.figure(figsize=(10, 10))
sns.regplot(diamonds.x, diamonds.price, scatter=True)
plt.ylim(0,20000)
# Out:
# C:\Users\rana_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 20000.0)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.x, diamonds.price)
r2 = r_value ** 2
slope
# Out:
# 3145.412947690132

# %%
b =plt.figure(figsize=(10, 10))
sns.regplot(diamonds.y, diamonds.price, scatter=True)
plt.ylim(0,20000)
# Out:
# C:\Users\rana_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 20000.0)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.y, diamonds.price)
r2 = r_value ** 2
slope
# Out:
# 3051.4891298768366

# %%
c =plt.figure(figsize=(10, 10))
sns.regplot(diamonds.z, diamonds.price, scatter=True)
plt.ylim(0,20000)
# Out:
# C:\Users\rana_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 20000.0)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.z, diamonds.price)
r2 = r_value ** 2
slope
# Out:
# 5022.405509422201

# %% [markdown]
# There is also a very strong correlation with the price and the three dimensions of diamonds. When x, y and z increase one point the price of the diamond increases 3145 , 3051 , 5022 $ respectively

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
